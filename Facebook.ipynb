# %%
import pandas as pd
import pandas as np

# %%
df = pd.read_csv(r"C:\Users\abhis\Downloads\Facebook.csv", sep = ';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df1 = df.iloc[:,:5]
df1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday
# 0              139441   Photo         2          12             4
# 1              139441  Status         2          12             3
# 2              139441   Photo         3          12             3
# 3              139441   Photo         2          12             2
# 4              139441   Photo         2          12             2
# ..                ...     ...       ...         ...           ...
# 495             85093   Photo         3           1             7
# 496             81370   Photo         2           1             5
# 497             81370   Photo         1           1             5
# 498             81370   Photo         3           1             4
# 499             81370   Photo         2           1             4
#
# [500 rows x 5 columns]

# %%
df2 = df.iloc[:,15:]
df2
# Out:
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 4 columns]

# %%
dm1 = pd.concat([df1, df2], axis = 1)
dm1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  comment  \
# 0              139441   Photo         2          12             4        4
# 1              139441  Status         2          12             3        5
# 2              139441   Photo         3          12             3        0
# 3              139441   Photo         2          12             2       58
# 4              139441   Photo         2          12             2       19
# ..                ...     ...       ...         ...           ...      ...
# 495             85093   Photo         3           1             7        5
# 496             81370   Photo         2           1             5        0
# 497             81370   Photo         1           1             5        4
# 498             81370   Photo         3           1             4        7
# 499             81370   Photo         2           1             4        0
#
#        like  share  Total Interactions
# ...

# %%
df3 = dm1.iloc[:150,:]
df3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  comment  \
# 0              139441   Photo         2          12             4        4
# 1              139441  Status         2          12             3        5
# 2              139441   Photo         3          12             3        0
# 3              139441   Photo         2          12             2       58
# 4              139441   Photo         2          12             2       19
# ..                ...     ...       ...         ...           ...      ...
# 145            136013   Photo         1          10             1        6
# 146            136013   Photo         3          10             1        0
# 147            135713   Photo         3          10             7        0
# 148            135713  Status         2          10             7        3
# 149            135713    Link         1          10             6        0
#
#        like  share  Total Interactions
# ...

# %%
df4 = dm1.iloc[350:,:]
df4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  comment  \
# 350            116435   Photo         2           5             5        3
# 351            116435   Photo         3           5             4        4
# 352            116435  Status         1           5             4        6
# 353            116435   Photo         3           5             3        4
# 354            116435   Photo         2           5             2        2
# ..                ...     ...       ...         ...           ...      ...
# 495             85093   Photo         3           1             7        5
# 496             81370   Photo         2           1             5        0
# 497             81370   Photo         1           1             5        4
# 498             81370   Photo         3           1             4        7
# 499             81370   Photo         2           1             4        0
#
#       like  share  Total Interactions
# ...

# %%
dm2 = pd.concat([df3, df4])
dm2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  comment  \
# 0              139441   Photo         2          12             4        4
# 1              139441  Status         2          12             3        5
# 2              139441   Photo         3          12             3        0
# 3              139441   Photo         2          12             2       58
# 4              139441   Photo         2          12             2       19
# ..                ...     ...       ...         ...           ...      ...
# 495             85093   Photo         3           1             7        5
# 496             81370   Photo         2           1             5        0
# 497             81370   Photo         1           1             5        4
# 498             81370   Photo         3           1             4        7
# 499             81370   Photo         2           1             4        0
#
#        like  share  Total Interactions
# ...

# %%
sorted_data = dm2.sort_values('Page total likes', ascending = False)
sorted_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  comment  \
# 0              139441   Photo         2          12             4        4
# 8              139441  Status         2          12             7        0
# 1              139441  Status         2          12             3        5
# 12             139441   Photo         2          12             5        0
# 11             139441   Photo         2          12             5        0
# ..                ...     ...       ...         ...           ...      ...
# 495             85093   Photo         3           1             7        5
# 496             81370   Photo         2           1             5        0
# 497             81370   Photo         1           1             5        4
# 498             81370   Photo         3           1             4        7
# 499             81370   Photo         2           1             4        0
#
#       like  share  Total Interactions
# ...

# %%
dt = dm2.transpose()
dt
# Out:
#                        0       1       2       3       4       5       6    \
# Page total likes    139441  139441  139441  139441  139441  139441  139441
# Type                 Photo  Status   Photo   Photo   Photo  Status   Photo
# Category                 2       2       3       2       2       2       3
# Post Month              12      12      12      12      12      12      12
# Post Weekday             4       3       3       2       2       1       1
# comment                  4       5       0      58      19       1       3
# like                  79.0   130.0    66.0  1572.0   325.0   152.0   249.0
# share                 17.0    29.0    14.0   147.0    49.0    33.0    27.0
# Total Interactions     100     164      80    1777     393     186     279
#
#                        7       8       9    ...    490    491    492    493  \
# Page total likes    139441  139441  139441  ...  85979  85979  85979  85093
# ...

# %%
dm2.shape
# Out:
# (300, 9)

# %%
dfrs = pd.pivot_table(dm2.head(), index = ['Type','Category'], values = 'like')
dfrs
# Out:
#                        like
# Type   Category
# Photo  2         658.666667
#        3          66.000000
# Status 2         130.000000

# %%
arr = np.array(df)
arr
# Out:
# <StringArray>
# [
# ["[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
# ...

# %%
arr2 = arr.reshape(-1)

# %%
arr2
# Out:
# <StringArray>
# ["[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  "[139441 'Photo' 2 12 4 3 0.0 2752 5091 178 109 159 3078 1640 119 4 79.0\n 17.0 100]",
#  ...
# ...

# %%
stack_df = df.stack()
stack_df
# Out:
# 0    Page total likes                                                       139441
#      Type                                                                    Photo
#      Category                                                                    2
#      Post Month                                                                 12
#      Post Weekday                                                                4
#                                                                              ...
# 499  Lifetime People who have liked your Page and engaged with your post       316
#      comment                                                                     0
#      like                                                                     91.0
#      share                                                                    28.0
#      Total Interactions                                                        119
# Length: 9494, dtype: object

# %%
unstacked_df = df.unstack()
unstacked_df
# Out:
# Page total likes    0      139441
#                     1      139441
#                     2      139441
#                     3      139441
#                     4      139441
#                             ...
# Total Interactions  495        84
#                     496        75
#                     497       115
#                     498       136
#                     499       119
# Length: 9500, dtype: object
