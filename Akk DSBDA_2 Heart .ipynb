# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\abhis\Downloads\heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df1 = df.iloc[:,[0,3]]
df1
# Out:
#       age  trestbps
# 0      52       125
# 1      53       140
# 2      70       145
# 3      61       148
# 4      62       138
# ...   ...       ...
# 1020   59       140
# 1021   60       125
# 1022   47       110
# 1023   50       110
# 1024   54       120
#
# [1025 rows x 2 columns]

# %%
df2 = df.iloc[:,[0,4]]
df2
# Out:
#       age  chol
# 0      52   212
# 1      53   203
# 2      70   174
# 3      61   203
# 4      62   294
# ...   ...   ...
# 1020   59   221
# 1021   60   258
# 1022   47   275
# 1023   50   254
# 1024   54   188
#
# [1025 rows x 2 columns]

# %%
di = pd.concat([df1, df2], axis = 1)
di
# Out:
#       age  trestbps  age  chol
# 0      52       125   52   212
# 1      53       140   53   203
# 2      70       145   70   174
# 3      61       148   61   203
# 4      62       138   62   294
# ...   ...       ...  ...   ...
# 1020   59       140   59   221
# 1021   60       125   60   258
# 1022   47       110   47   275
# 1023   50       110   50   254
# 1024   54       120   54   188
#
# [1025 rows x 4 columns]

# %%
df['sex'] = df['sex'].replace({1:'Female', 0:'Male'})

# %%
df
# Out:
#       age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52  Female   0       125   212    0        1      168      0      1.0
# 1      53  Female   0       140   203    1        0      155      1      3.1
# 2      70  Female   0       145   174    0        1      125      1      2.6
# 3      61  Female   0       148   203    0        1      161      0      0.0
# 4      62    Male   0       138   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59  Female   1       140   221    0        1      164      1      0.0
# 1021   60  Female   0       125   258    0        0      141      1      2.8
# 1022   47  Female   0       110   275    0        0      118      1      1.0
# 1023   50    Male   0       110   254    0        0      159      0      0.0
# 1024   54  Female   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
from sklearn import preprocessing

# %%
df['sex'] = preprocessing.LabelEncoder().fit_transform(df['sex'])

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    0   0       125   212    0        1      168      0      1.0
# 1      53    0   0       140   203    1        0      155      1      3.1
# 2      70    0   0       145   174    0        1      125      1      2.6
# 3      61    0   0       148   203    0        1      161      0      0.0
# 4      62    1   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    0   1       140   221    0        1      164      1      0.0
# 1021   60    0   0       125   258    0        0      141      1      2.8
# 1022   47    0   0       110   275    0        0      118      1      1.0
# 1023   50    1   0       110   254    0        0      159      0      0.0
# 1024   54    0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
oHE = pd.get_dummies(df, columns = ['sex','cp','fbs','restecg','exang','slope','ca','thal','target'])
oHE
# Out:
#       age  trestbps  chol  thalach  oldpeak  sex_0  sex_1  cp_0  cp_1  cp_2  \
# 0      52       125   212      168      1.0      1      0     1     0     0
# 1      53       140   203      155      3.1      1      0     1     0     0
# 2      70       145   174      125      2.6      1      0     1     0     0
# 3      61       148   203      161      0.0      1      0     1     0     0
# 4      62       138   294      106      1.9      0      1     1     0     0
# ...   ...       ...   ...      ...      ...    ...    ...   ...   ...   ...
# 1020   59       140   221      164      0.0      1      0     0     1     0
# 1021   60       125   258      141      2.8      1      0     1     0     0
# 1022   47       110   275      118      1.0      1      0     1     0     0
# 1023   50       110   254      159      0.0      0      1     1     0     0
# 1024   54       120   188      113      1.4      1      0     1     0     0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['age']]
y = df[['chol']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 42)

# %%
x_train
# Out:
#       age
# 949    57
# 1021   60
# 94     62
# 33     70
# 259    66
# ...   ...
# 700    41
# 71     61
# 106    51
# 270    43
# 860    52
#
# [768 rows x 1 columns]

# %%
x_test
# Out:
#      age
# 527   62
# 359   53
# 447   55
# 31    50
# 621   48
# ..   ...
# 940   57
# 787   51
# 926   54
# 249   42
# 552   43
#
# [257 rows x 1 columns]

# %%
y_train
# Out:
#       chol
# 949    207
# 1021   258
# 94     208
# 33     269
# 259    302
# ...    ...
# 700    214
# 71     207
# 106    299
# 270    211
# 860    230
#
# [768 rows x 1 columns]

# %%
y_test
# Out:
#      chol
# 527   209
# 359   216
# 447   289
# 31    244
# 621   256
# ..    ...
# 940   241
# 787   298
# 926   206
# 249   180
# 552   341
#
# [257 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model = model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[253.95360201],
#        [242.7297647 ],
#        [245.22395077],
#        [238.9884856 ],
#        [236.49429953],
#        [268.91871841],
#        [256.44778807],
#        [260.18906717],
#        [236.49429953],
#        [263.93034627],
#        [251.45941594],
#        [250.2123229 ],
#        [229.01174133],
#        [247.71813684],
#        [246.4710438 ],
#        [247.71813684],
#        [252.70650897],
#        [227.7646483 ],
#        [241.48267167],
#        [243.97685774],
#        [247.71813684],
#        [251.45941594],
#        [248.96522987],
#        [234.00011347],
#        [247.71813684],
#        [224.0233692 ],
#        [236.49429953],
#        [241.48267167],
#        [255.20069504],
#        [252.70650897],
#        [250.2123229 ],
#        [240.23557864],
#        [236.49429953],
#        [242.7297647 ],
#        [229.01174133],
#        [246.4710438 ],
#        [247.71813684],
#        [258.94197414],
#        [265.17743931],
#        [231.5059274 ],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y, color = 'red', label = 'Actual')
plt.plot(x_test, y_pred, color = 'black', label = 'Predicted')
plt.xlabel('Age')
plt.ylabel('Chol')
plt.title('Age X Chol')
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 43.09227115290085

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3586.418639465682
